# %%
# Practice with Lists

numbers = [10, 20, 30, 40, 50]

print(numbers)
print(numbers[0])
print(numbers[-1])
print(len(numbers))
print(sum(numbers))
# Out:
# [10, 20, 30, 40, 50]
# 10
# 50
# 5
# 150

# %%
# Practice with for loops

numbers = [10, 20, 30, 40, 50]

for n in numbers:
    print("Number:", n)
# Out:
# Number: 10
# Number: 20
# Number: 30
# Number: 40
# Number: 50

# %%
age = 25

if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %%
customer = {
    "name": "Alice",
    "age": 30,
    "churn": "Yes"
}

print(customer["name"])
print(customer["age"])
print(customer["churn"])
# Out:
# Alice
# 30
# Yes

# %%
def greet(name):
    return f"Hello, {name}"

print(greet("Hank"))
# Out:
# Hello, Hank

# %%
monthly_charges = [20, 35, 50, 70, 100]

high_value = []

for charge in monthly_charges:
    if charge > 50:
        high_value.append(charge)

print(high_value)
# Out:
# [70, 100]
